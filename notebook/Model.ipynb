# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns



from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from xgboost import XGBClassifier

# %%
df = pd.read_csv("data\predictive_maintenance.csv")
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19244\78431725.py:1: SyntaxWarning: invalid escape sequence '\p'
#   df = pd.read_csv("data\predictive_maintenance.csv")
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target
# 0                    1551         42.8                0       0
# 1                    1408         46.3                3       0
# 2                    1498         49.4                5       0
# 3                    1433         39.5                7       0
# 4                    1408         40.0                9       0

# %%
df.drop(['UDI', 'Product ID'], axis = 1, inplace= True)
df.head()
# Out:
#   Type  Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0    M                298.1                    308.6                    1551
# 1    L                298.2                    308.7                    1408
# 2    L                298.1                    308.5                    1498
# 3    L                298.2                    308.6                    1433
# 4    L                298.2                    308.7                    1408
#
#    Torque [Nm]  Tool wear [min]  Target
# 0         42.8                0       0
# 1         46.3                3       0
# 2         49.4                5       0
# 3         39.5                7       0
# 4         40.0                9       0

# %%
X = df.drop('Target', axis= 1)
y = df['Target']

# %%
X.shape, y.shape
# Out:
# ((10000, 6), (10000,))

# %%
cal_cols = X.select_dtypes(object).columns
num_cols = X.select_dtypes('number').columns

# %%
scaler = MinMaxScaler()
ohe = OneHotEncoder()

preprocessor = ColumnTransformer(

[ 
       ("OneHotEncoder", ohe, cal_cols),
       ("MinMaxScaler", scaler, num_cols)
]
)

# %%
X = preprocessor.fit_transform(X)

# %%
X
# Out:
# array([[0.        , 0.        , 1.        , ..., 0.22293364, 0.53571429,
#         0.        ],
#        [0.        , 1.        , 0.        , ..., 0.13969732, 0.58379121,
#         0.01185771],
#        [0.        , 1.        , 0.        , ..., 0.19208382, 0.62637363,
#         0.01976285],
#        ...,
#        [0.        , 0.        , 1.        , ..., 0.27764843, 0.40659341,
#         0.08695652],
#        [1.        , 0.        , 0.        , ..., 0.13969732, 0.61401099,
#         0.09881423],
#        [0.        , 0.        , 1.        , ..., 0.19324796, 0.5       ,
#         0.11857708]], shape=(10000, 8))

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size= 0.3, random_state= 1, stratify= y)

# %%
lreg = LogisticRegression()
dtc  = DecisionTreeClassifier()
rfc  = RandomForestClassifier()

# %% [markdown]
# Base performance test

# %%
for i in [lreg, dtc, rfc]:
    i.fit(x_train, y_train)
    pred = i.predict(x_test)

    
    print("***********************")
    print(i)
    print(classification_report(y_test, pred))
    print(f1_score(y_test, pred))
# Out:
# ***********************
# LogisticRegression()
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      2898
#            1       1.00      0.02      0.04       102
#
#     accuracy                           0.97      3000
#    macro avg       0.98      0.51      0.51      3000
# weighted avg       0.97      0.97      0.95      3000
#
# 0.038461538461538464
# ***********************
# DecisionTreeClassifier()
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2898
#            1       0.61      0.64      0.62       102
#
#     accuracy                           0.97      3000
#    macro avg       0.80      0.81      0.81      3000
# weighted avg       0.97      0.97      0.97      3000
#
# 0.625
# ***********************
# RandomForestClassifier()
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      2898
#            1       0.82      0.44      0.57       102
#
#     accuracy                           0.98      3000
#    macro avg       0.90      0.72      0.78      3000
# weighted avg       0.98      0.98      0.97      3000
#
# 0.5732484076433121

# %%
param_dist = {
    'n_estimators': [250, 300, 350],
    'max_depth': [15, 20, 25],
    'min_samples_split': [5, 7, 10],
    'class_weight': [ {0:1,1:3},{0:1,1:4}]
}

random_search = RandomizedSearchCV(
    estimator=rfc, 
    param_distributions=param_dist, 
    n_iter=20,  # Number of random combinations
    cv=5,  # 5-fold cross-validation
    scoring='f1', 
    random_state=42,
    n_jobs=-1,
    return_train_score= True
)


# Fit to data
random_search.fit(x_train, y_train)

# Best parameters
print("Best Parameters:", random_search.best_params_)
# Out:
# Best Parameters: {'n_estimators': 350, 'min_samples_split': 10, 'max_depth': 25, 'class_weight': {0: 1, 1: 3}}

# %%
pd.set_option('display.max_colwidth', None)
resutls_rfc = pd.DataFrame(random_search.cv_results_)
resutls_rfc[['params','mean_train_score','mean_test_score','rank_test_score']].sort_values(by = 'rank_test_score')
# Out:
#                                                                                            params  \
# 12  {'n_estimators': 350, 'min_samples_split': 10, 'max_depth': 25, 'class_weight': {0: 1, 1: 3}}
# 13  {'n_estimators': 250, 'min_samples_split': 10, 'max_depth': 15, 'class_weight': {0: 1, 1: 3}}
# 3    {'n_estimators': 250, 'min_samples_split': 7, 'max_depth': 20, 'class_weight': {0: 1, 1: 3}}
# 15   {'n_estimators': 300, 'min_samples_split': 7, 'max_depth': 15, 'class_weight': {0: 1, 1: 3}}
# 6   {'n_estimators': 350, 'min_samples_split': 10, 'max_depth': 20, 'class_weight': {0: 1, 1: 3}}
# 1    {'n_estimators': 300, 'min_samples_split': 7, 'max_depth': 25, 'class_weight': {0: 1, 1: 4}}
# 11  {'n_estimators': 350, 'min_samples_split': 10, 'max_depth': 15, 'class_weight': {0: 1, 1: 3}}
# 9    {'n_estimators': 350, 'min_samples_split': 7, 'max_depth': 15, 'class_weight': {0: 1, 1: 4}}
# 17  {'n_estimators': 250, 'min_samples_split': 10, 'max_depth': 25, 'class_weight': {0: 1, 1: 3}}
# 7   {'n_estimators': 300, 'min_samples_split': 10, 'max_depth': 25, 'class_weight': {0: 1, 1: 4}}
# 4   {'n_estimators': 350, 'min_samples_split': 10, 'max_depth': 20, 'class_weight': {0: 1, 1: 4}}
# 10   {'n_estimators': 300, 'min_samples_split': 7, 'max_depth': 20, 'class_weight': {0: 1, 1: 3}}
# 14  {'n_estimators': 300, 'min_samples_split': 10, 'max_depth': 15, 'class_weight': {0: 1, 1: 4}}
# 2    {'n_estimators': 250, 'min_samples_split': 7, 'max_depth': 25, 'class_weight': {0: 1, 1: 4}}
# 0    {'n_estimators': 300, 'min_samples_split': 5, 'max_depth': 25, 'class_weight': {0: 1, 1: 3}}
# 8    {'n_estimators': 250, 'min_samples_split': 7, 'max_depth': 15, 'class_weight': {0: 1, 1: 3}}
# 18   {'n_estimators': 250, 'min_samples_split': 5, 'max_depth': 25, 'class_weight': {0: 1, 1: 4}}
# 19  {'n_estimators': 250, 'min_samples_split': 10, 'max_depth': 15, 'class_weight': {0: 1, 1: 4}}
# 5    {'n_estimators': 350, 'min_samples_split': 7, 'max_depth': 15, 'class_weight': {0: 1, 1: 3}}
# 16   {'n_estimators': 300, 'min_samples_split': 5, 'max_depth': 20, 'class_weight': {0: 1, 1: 4}}
#
#     mean_train_score  mean_test_score  rank_test_score
# 12          0.928043         0.684508                1
# 13          0.925940         0.679730                2
# 3           0.953122         0.675719                3
# 15          0.954606         0.675375                4
# 6           0.926365         0.674659                5
# 1           0.962627         0.674096                6
# 11          0.930304         0.672675                7
# 9           0.961030         0.671469                8
# 17          0.929884         0.669151                9
# 7           0.937814         0.668985               10
# 4           0.936057         0.666008               11
# 10          0.951483         0.663520               12
# 14          0.937211         0.663332               13
# 2           0.961429         0.662724               14
# 0           0.984467         0.661173               15
# 8           0.953633         0.660173               16
# 18          0.993642         0.659603               17
# 19          0.936659         0.658311               18
# 5           0.954750         0.655449               19
# 16          0.992550         0.653413               20

# %%
param_dist = {
    'splitter': ['best', 'random'],
    'max_depth': [10, 20, 30, 50],
    'min_samples_split': [2, 5, 10],
    'max_features': [ 'log2', None],
}


# Perform Randomized Search
random_search = RandomizedSearchCV(
    estimator=dtc,
    param_distributions=param_dist,
    n_iter=20,  # Number of random combinations
    cv=5,  # 5-fold cross-validation
    scoring='f1',
    random_state=42,
    n_jobs=-1,
    return_train_score= True
)

random_search.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_iter=20,
#                    n_jobs=-1,
#                    param_distributions={'max_depth': [10, 20, 30, 50],
#                                         'max_features': ['log2', None],
#                                         'min_samples_split': [2, 5, 10],
#                                         'splitter': ['best', 'random']},
#                    random_state=42, return_train_score=True, scoring='f1')

# %%
pd.set_option('display.max_colwidth', None)
resutls_dtc = pd.DataFrame(random_search.cv_results_)
resutls_dtc[['params','mean_train_score','mean_test_score','rank_test_score']].sort_values(by = 'rank_test_score')
# Out:
#                                                                                       params  \
# 10       {'splitter': 'best', 'min_samples_split': 5, 'max_features': None, 'max_depth': 10}
# 12       {'splitter': 'best', 'min_samples_split': 2, 'max_features': None, 'max_depth': 10}
# 2      {'splitter': 'best', 'min_samples_split': 5, 'max_features': 'log2', 'max_depth': 30}
# 4      {'splitter': 'best', 'min_samples_split': 2, 'max_features': 'log2', 'max_depth': 30}
# 3      {'splitter': 'random', 'min_samples_split': 2, 'max_features': None, 'max_depth': 50}
# 17     {'splitter': 'random', 'min_samples_split': 5, 'max_features': None, 'max_depth': 50}
# 8     {'splitter': 'best', 'min_samples_split': 10, 'max_features': 'log2', 'max_depth': 10}
# 6      {'splitter': 'best', 'min_samples_split': 2, 'max_features': 'log2', 'max_depth': 20}
# 1     {'splitter': 'best', 'min_samples_split': 10, 'max_features': 'log2', 'max_depth': 50}
# 14     {'splitter': 'random', 'min_samples_split': 5, 'max_features': None, 'max_depth': 30}
# 19     {'splitter': 'random', 'min_samples_split': 5, 'max_features': None, 'max_depth': 10}
# 7      {'splitter': 'random', 'min_samples_split': 2, 'max_features': None, 'max_depth': 20}
# 15   {'splitter': 'random', 'min_samples_split': 2, 'max_features': 'log2', 'max_depth': 20}
# 5    {'splitter': 'random', 'min_samples_split': 2, 'max_features': 'log2', 'max_depth': 50}
# 9    {'splitter': 'random', 'min_samples_split': 2, 'max_features': 'log2', 'max_depth': 30}
# 18   {'splitter': 'random', 'min_samples_split': 5, 'max_features': 'log2', 'max_depth': 20}
# 13   {'splitter': 'random', 'min_samples_split': 5, 'max_features': 'log2', 'max_depth': 50}
# 0    {'splitter': 'random', 'min_samples_split': 5, 'max_features': 'log2', 'max_depth': 30}
# 16  {'splitter': 'random', 'min_samples_split': 10, 'max_features': 'log2', 'max_depth': 20}
# 11   {'splitter': 'random', 'min_samples_split': 5, 'max_features': 'log2', 'max_depth': 10}
#
#     mean_train_score  mean_test_score  rank_test_score
# 10          0.918964         0.694234                1
# 12          0.938348         0.680403                2
# 2           0.928053         0.631657                3
# 4           1.000000         0.631219                4
# 3           1.000000         0.607701                5
# 17          0.875647         0.606800                6
# 8           0.794492         0.595334                7
# 6           1.000000         0.591788                8
# 1           0.858917         0.582193                9
# 14          0.862558         0.573882               10
# 19          0.741593         0.557040               11
# 7           0.997370         0.536942               12
# 15          0.979064         0.460885               13
# 5           1.000000         0.457976               14
# 9           1.000000         0.451463               15
# 18          0.729644         0.445097               16
# 13          0.735588         0.439996               17
# 0           0.758315         0.430224               18
# 16          0.603326         0.389054               19
# 11          0.472422         0.341660               20

# %% [markdown]
# Conclusion -> Sampling of data required due to heavy imbalance

# %%
from imblearn.over_sampling import SMOTE

sampler = SMOTE()

x_sampled, y_sampled = sampler.fit_resample(X,y)

# %%
y_sampled.value_counts()
# Out:
# Target
# 0    9661
# 1    9661
# Name: count, dtype: int64

# %%
x_train_sampled, x_test_sampled, y_train_sampled, y_test_sampled = train_test_split(x_sampled, y_sampled, test_size = 0.3, random_state= 1, )

# %%
for i in [lreg, dtc, rfc]:
    i.fit(x_train_sampled, y_train_sampled)
    pred = i.predict(x_test_sampled)

    
    print("***********************")
    print(i)
    print(classification_report(y_test_sampled, pred))
    print(f1_score(y_test_sampled, pred))
# Out:
# ***********************
# LogisticRegression()
#               precision    recall  f1-score   support
#
#            0       0.83      0.82      0.82      2421
#            1       0.82      0.83      0.82      2410
#
#     accuracy                           0.82      4831
#    macro avg       0.82      0.82      0.82      4831
# weighted avg       0.82      0.82      0.82      4831
#
# 0.8236024844720496
# ***********************
# DecisionTreeClassifier()
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      2421
#            1       0.96      0.97      0.96      2410
#
#     accuracy                           0.96      4831
#    macro avg       0.96      0.96      0.96      4831
# weighted avg       0.96      0.96      0.96      4831
#
# 0.9621822690638562
# ***********************
# RandomForestClassifier()
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98      2421
#            1       0.97      0.98      0.98      2410
#
#     accuracy                           0.98      4831
#    macro avg       0.98      0.98      0.98      4831
# weighted avg       0.98      0.98      0.98      4831
#
# 0.9781172584640793

# %%
param_dist = {
    'criterion' : [ 'entropy', 'log_loss'],
    'n_estimators': [100, 200, 250, 500],
    'max_depth': [15, 17, 20],
    'min_samples_split': [2, 3],
}

random_search = GridSearchCV(
    estimator=rfc, 
    param_grid =param_dist,   # Number of random combinations
    cv=5,  # 5-fold cross-validation
    scoring='f1', 
    n_jobs=-1,
    return_train_score= True
)


# Fit to data
random_search.fit(x_sampled, y_sampled)

# Best parameters
print("Best Parameters:", random_search.best_params_)
# Out:
# Best Parameters: {'criterion': 'entropy', 'max_depth': 17, 'min_samples_split': 2, 'n_estimators': 100}

# %%
pd.set_option('display.max_colwidth', None)
resutls_rfc = pd.DataFrame(random_search.cv_results_)
resutls_rfc[['params','mean_train_score','mean_test_score','rank_test_score']].sort_values(by = 'rank_test_score')
# Out:
#                                                                                      params  \
# 8    {'criterion': 'entropy', 'max_depth': 17, 'min_samples_split': 2, 'n_estimators': 100}
# 40  {'criterion': 'log_loss', 'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 100}
# 21   {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 3, 'n_estimators': 200}
# 18   {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 250}
# 44  {'criterion': 'log_loss', 'max_depth': 20, 'min_samples_split': 3, 'n_estimators': 100}
# 23   {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 3, 'n_estimators': 500}
# 41  {'criterion': 'log_loss', 'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 200}
# 46  {'criterion': 'log_loss', 'max_depth': 20, 'min_samples_split': 3, 'n_estimators': 250}
# 12   {'criterion': 'entropy', 'max_depth': 17, 'min_samples_split': 3, 'n_estimators': 100}
# 17   {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 200}
# 22   {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 3, 'n_estimators': 250}
# 47  {'criterion': 'log_loss', 'max_depth': 20, 'min_samples_split': 3, 'n_estimators': 500}
# 32  {'criterion': 'log_loss', 'max_depth': 17, 'min_samples_split': 2, 'n_estimators': 100}
# 42  {'criterion': 'log_loss', 'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 250}
# 15   {'criterion': 'entropy', 'max_depth': 17, 'min_samples_split': 3, 'n_estimators': 500}
# 20   {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 3, 'n_estimators': 100}
# 37  {'criterion': 'log_loss', 'max_depth': 17, 'min_samples_split': 3, 'n_estimators': 200}
# 39  {'criterion': 'log_loss', 'max_depth': 17, 'min_samples_split': 3, 'n_estimators': 500}
# 43  {'criterion': 'log_loss', 'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 500}
# 34  {'criterion': 'log_loss', 'max_depth': 17, 'min_samples_split': 2, 'n_estimators': 250}
# 10   {'criterion': 'entropy', 'max_depth': 17, 'min_samples_split': 2, 'n_estimators': 250}
# 33  {'criterion': 'log_loss', 'max_depth': 17, 'min_samples_split': 2, 'n_estimators': 200}
# 13   {'criterion': 'entropy', 'max_depth': 17, 'min_samples_split': 3, 'n_estimators': 200}
# 9    {'criterion': 'entropy', 'max_depth': 17, 'min_samples_split': 2, 'n_estimators': 200}
# 19   {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 500}
# 14   {'criterion': 'entropy', 'max_depth': 17, 'min_samples_split': 3, 'n_estimators': 250}
# 0    {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 100}
# 16   {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 100}
# 3    {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 500}
# 35  {'criterion': 'log_loss', 'max_depth': 17, 'min_samples_split': 2, 'n_estimators': 500}
# 2    {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 250}
# 26  {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 250}
# 38  {'criterion': 'log_loss', 'max_depth': 17, 'min_samples_split': 3, 'n_estimators': 250}
# 36  {'criterion': 'log_loss', 'max_depth': 17, 'min_samples_split': 3, 'n_estimators': 100}
# 25  {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 200}
# 45  {'criterion': 'log_loss', 'max_depth': 20, 'min_samples_split': 3, 'n_estimators': 200}
# 31  {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_split': 3, 'n_estimators': 500}
# 29  {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_split': 3, 'n_estimators': 200}
# 1    {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 200}
# 11   {'criterion': 'entropy', 'max_depth': 17, 'min_samples_split': 2, 'n_estimators': 500}
# 30  {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_split': 3, 'n_estimators': 250}
# 24  {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 100}
# 6    {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 3, 'n_estimators': 250}
# 7    {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 3, 'n_estimators': 500}
# 27  {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 500}
# 28  {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_split': 3, 'n_estimators': 100}
# 5    {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 3, 'n_estimators': 200}
# 4    {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 3, 'n_estimators': 100}
#
#     mean_train_score  mean_test_score  rank_test_score
# 8           0.999780         0.938847                1
# 40          0.999987         0.938490                2
# 21          1.000000         0.937587                3
# 18          1.000000         0.936654                4
# 44          0.999922         0.936151                5
# 23          1.000000         0.935822                6
# 41          1.000000         0.935561                7
# 46          1.000000         0.935370                8
# 12          0.999664         0.935295                9
# 17          1.000000         0.935290               10
# 22          1.000000         0.935242               11
# 47          1.000000         0.935058               12
# 32          0.999754         0.934989               13
# 42          1.000000         0.934836               14
# 15          0.999702         0.934817               15
# 20          0.999961         0.934674               16
# 37          0.999702         0.934428               17
# 39          0.999780         0.934360               18
# 43          1.000000         0.934325               19
# 34          0.999754         0.934212               20
# 10          0.999715         0.934105               21
# 33          0.999819         0.933852               22
# 13          0.999638         0.933788               23
# 9           0.999819         0.933750               24
# 19          1.000000         0.933728               25
# 14          0.999715         0.933576               26
# 0           0.998525         0.933392               27
# 16          1.000000         0.933335               28
# 3           0.998655         0.933308               29
# 35          0.999793         0.933204               30
# 2           0.998823         0.933111               31
# 26          0.998655         0.933051               32
# 38          0.999625         0.933015               33
# 36          0.999638         0.933005               34
# 25          0.998512         0.932981               35
# 45          1.000000         0.932946               36
# 31          0.998422         0.932938               37
# 29          0.998461         0.932891               38
# 1           0.998538         0.932860               39
# 11          0.999780         0.932696               40
# 30          0.998460         0.932568               41
# 24          0.998487         0.932252               42
# 6           0.998357         0.931969               43
# 7           0.998525         0.931909               44
# 27          0.998719         0.931594               45
# 28          0.998086         0.931563               46
# 5           0.998474         0.931252               47
# 4           0.998280         0.931020               48

# %%
xgb = XGBClassifier(verbosity = 0)


param_xgb = {'eta':[0.3,0.1,0.2,0.01],
             'max_depth':[3],
             'n_estimators':[100,250,500],
             'min_child_weight':[17,18],
             'reg_lamda':[0,0.5,1,2,3],
             'alpha':[0,0.5,1,2,3]
}


search_xgb = GridSearchCV(estimator = xgb,
                          param_grid = param_xgb,
                          scoring = 'f1',
                         return_train_score=True,
                          cv = 5)


search_xgb.fit(x_sampled, y_sampled)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, feature_weights=None,
#                                      gamma=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=Non...
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None, ...),
#              param_grid={'alpha': [0, 0.5, 1, 2, 3],
#                          'eta': [0.3, 0.1, 0.2, 0.01], 'max_depth': [3],
#                          'min_child_weight': [17, 18],
#                          'n_estimators': [100, 250, 500],
#                          'reg_lamda': [0, 0.5, 1, 2, 3]},
#              return_train_score=True, scoring='f1')

# %%
pd.set_option('display.max_colwidth', None)
resutls_xgb = pd.DataFrame(search_xgb.cv_results_)
resutls_xgb[['params','mean_train_score','mean_test_score','rank_test_score']].sort_values(by = 'rank_test_score')
# Out:
#                                                                                                       params  \
# 494    {'alpha': 3, 'eta': 0.3, 'max_depth': 3, 'min_child_weight': 17, 'n_estimators': 500, 'reg_lamda': 3}
# 492    {'alpha': 3, 'eta': 0.3, 'max_depth': 3, 'min_child_weight': 17, 'n_estimators': 500, 'reg_lamda': 1}
# 490    {'alpha': 3, 'eta': 0.3, 'max_depth': 3, 'min_child_weight': 17, 'n_estimators': 500, 'reg_lamda': 0}
# 491  {'alpha': 3, 'eta': 0.3, 'max_depth': 3, 'min_child_weight': 17, 'n_estimators': 500, 'reg_lamda': 0.5}
# 493    {'alpha': 3, 'eta': 0.3, 'max_depth': 3, 'min_child_weight': 17, 'n_estimators': 500, 'reg_lamda': 2}
# ..                                                                                                       ...
# 544    {'alpha': 3, 'eta': 0.2, 'max_depth': 3, 'min_child_weight': 17, 'n_estimators': 100, 'reg_lamda': 3}
# 540    {'alpha': 3, 'eta': 0.2, 'max_depth': 3, 'min_child_weight': 17, 'n_estimators': 100, 'reg_lamda': 0}
# 541  {'alpha': 3, 'eta': 0.2, 'max_depth': 3, 'min_child_weight': 17, 'n_estimators': 100, 'reg_lamda': 0.5}
# 543    {'alpha': 3, 'eta': 0.2, 'max_depth': 3, 'min_child_weight': 17, 'n_estimators': 100, 'reg_lamda': 2}
# 542    {'alpha': 3, 'eta': 0.2, 'max_depth': 3, 'min_child_weight': 17, 'n_estimators': 100, 'reg_lamda': 1}
#
#      mean_train_score  mean_test_score  rank_test_score
# 494          0.986136         0.926286                1
# 492          0.986136         0.926286                1
# 490          0.986136         0.926286                1
# 491          0.986136         0.926286                1
# 493          0.986136         0.926286                1
# ..                ...              ...              ...
# 544          0.957055         0.898442              596
# 540          0.957055         0.898442              596
# 541          0.957055         0.898442              596
# 543          0.957055         0.898442              596
# 542          0.957055         0.898442              596
#
# [600 rows x 4 columns]
